# %% [markdown]
# # Final Project Part 2: Brief
# ### Perform EDA on data set
# _By: Francesco Yuri Tinelli (Washington, D.C.)_
#
# ---

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read in data

# %%
# Read in general data/details about the employees.
general_hr = pd.read_csv('./data/general_data.csv')

# Read in survey results pertaining to empolyees' responses on 
# environment, job, and work life balance satisfaction level.
employee_survey = pd.read_csv('./data/employee_survey_data.csv')

# %% [markdown]
# ### Exploratory and Statistical data analysis

# %% [markdown]
# #### Understanding the data

# %%
# First dataset of general employee information/details.
general_hr.head(5)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  \
# 0          2  Life Sciences              1           1  Female
# 1          1  Life Sciences              1           2  Female
# 2          4          Other              1           3    Male
# 3          5  Life Sciences              1           4    Male
# 4          1        Medical              1           5    Male
#
#            ...           NumCompaniesWorked Over18 PercentSalaryHike  \
# ...

# %%
# Second dataset of employees' responses to survey.
employee_survey.head(5)
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
# Check number of rows and columns as well as column names.
print(f'General HR data has {general_hr.shape[0]} rows and {general_hr.shape[1]} columns with the following column names:\n {general_hr.columns}.')
print(f'\nEmployee survey data has {employee_survey.shape[0]} rows and {employee_survey.shape[1]} columns with the following column names:\n {employee_survey.columns}.')
# Out:
# General HR data has 4410 rows and 24 columns with the following column names:
#  Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object').
#
# Employee survey data has 4410 rows and 4 columns with the following column names:
#  Index(['EmployeeID', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance'],
#       dtype='object').

# %%
# Check the data types
general_hr.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeID                   int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
# Check the data types
employee_survey.dtypes
# Out:
# EmployeeID                   int64
# EnvironmentSatisfaction    float64
# JobSatisfaction            float64
# WorkLifeBalance            float64
# dtype: object

# %% [markdown]
# #### Would be beneficl to combine these datasets to provide the model with more features.

# %% [markdown]
# #### Combine data per understanding and describe this dataset

# %%
# It would be beneficial to merge the two datasets and proceed with further exploratory and statistical data analysis.

# Check if 'EmployeeID' is unique/distinct in both datasets to use field for merge.
print(f"General HR data has {general_hr['EmployeeID'].nunique()} distinct employee IDs and \nEmployee survey data has {employee_survey['EmployeeID'].nunique()} distinct employee IDs.")
# Out:
# General HR data has 4410 distinct employee IDs and
# Employee survey data has 4410 distinct employee IDs.

# %%
# Merge the two dataset by 'EmployeeID' and using left join and call new data set 'hr'.
hr = pd.merge(general_hr,employee_survey,how='left',on='EmployeeID')

# Check number of rows and columns to confirm proper join.
print(f'New hr data set has {hr.shape[0]} rows and {hr.shape[1]} columns with the following column names:\n {hr.columns}.')
# Out:
# New hr data set has 4410 rows and 27 columns with the following column names:
#  Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance'],
#       dtype='object').

# %%
# Review basic statistics of combined dataset.
hr.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %% [markdown]
# Looks like there are null values for some columns.

# %% [markdown]
# #### Clean data for null/missing values

# %%
# Double-check null fields identified by count in 'hr.describe()'.
hr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# dtype: int64

# %%
# Percentage of missing nulls
hr.isnull().mean()
# Out:
# Age                        0.000000
# Attrition                  0.000000
# BusinessTravel             0.000000
# Department                 0.000000
# DistanceFromHome           0.000000
# Education                  0.000000
# EducationField             0.000000
# EmployeeCount              0.000000
# EmployeeID                 0.000000
# Gender                     0.000000
# JobLevel                   0.000000
# JobRole                    0.000000
# MaritalStatus              0.000000
# MonthlyIncome              0.000000
# NumCompaniesWorked         0.004308
# Over18                     0.000000
# PercentSalaryHike          0.000000
# StandardHours              0.000000
# StockOptionLevel           0.000000
# TotalWorkingYears          0.002041
# TrainingTimesLastYear      0.000000
# YearsAtCompany             0.000000
# YearsSinceLastPromotion    0.000000
# YearsWithCurrManager       0.000000
# EnvironmentSatisfaction    0.005669
# JobSatisfaction            0.004535
# ...

# %%
# Look at null values
hr[hr.isnull().any(axis=1)]
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 11     36        No      Travel_Rarely  Research & Development
# 23     42        No      Travel_Rarely  Research & Development
# 40     36        No  Travel_Frequently  Research & Development
# 84     31        No      Travel_Rarely  Research & Development
# 111    31        No      Travel_Rarely  Research & Development
# 115    27        No      Travel_Rarely                   Sales
# 124    26       Yes  Travel_Frequently                   Sales
# 137    43        No  Travel_Frequently                   Sales
# 195    26       Yes  Travel_Frequently  Research & Development
# 210    52        No      Travel_Rarely                   Sales
# 273    32        No      Travel_Rarely                   Sales
# 300    32        No  Travel_Frequently                   Sales
# 308    47       Yes  Travel_Frequently  Research & Development
# 313    26        No  Travel_Frequently  Research & Development
# ...

# %%
# Even though it is a small percentage of the dataset, it is preferable to keep the data/rows and fill them in.

# Fill in null values with mean of its column.
hr.fillna(value={'NumCompaniesWorked':hr['NumCompaniesWorked'].mean()},inplace=True)
hr.fillna(value={'TotalWorkingYears':hr['TotalWorkingYears'].mean()},inplace=True)
hr.fillna(value={'EnvironmentSatisfaction':hr['EnvironmentSatisfaction'].mean()},inplace=True)
hr.fillna(value={'JobSatisfaction':hr['JobSatisfaction'].mean()},inplace=True)
hr.fillna(value={'WorkLifeBalance':hr['WorkLifeBalance'].mean()},inplace=True)

# Confirm no null values.
hr.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# dtype: int64

# %% [markdown]
# ### Analyze and visualize dataset to learn more about attrition

# %%
# Determine the current attrition for company.
hr['Attrition'].value_counts(normalize=True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %% [markdown]
# 16% percent of the employees have left the company. Review the characteristics of employee attrition.

# %%
plt.style.use('seaborn-darkgrid')

# %% [markdown]
# Start with continuous variables.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))
#hr[hr['Attrition'] == 'Yes'].boxplot(by="Attrition",ax=ax,column=['Age', 'DistanceFromHome', 'Education','JobLevel'])
hr.boxplot(by="Attrition",ax=ax,column=['Age', 'DistanceFromHome', 'Education','JobLevel'])
plt.show()
# Out:
# C:\Users\ftine\Anaconda3\lib\site-packages\pandas\plotting\_core.py:2257: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   return_type=return_type, **kwds)

# %% [markdown]
# Takeaways:
# - Age, distance from home, and education have almost similar split for either staying or leaving.
# - Job level shows those who left are mostly lower job levels.

# %%
hr['JobLevel'][hr['Attrition']=='Yes'].value_counts(normalize=True)
# Out:
# 2    0.400844
# 1    0.354430
# 3    0.135021
# 4    0.071730
# 5    0.037975
# Name: JobLevel, dtype: float64

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))
#hr[hr['Attrition'] == 'Yes'].boxplot(by="Attrition",ax=ax,column=['MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','StockOptionLevel'])
hr.boxplot(by="Attrition",ax=ax,column=['MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','StockOptionLevel'])
plt.show()
# Out:
# C:\Users\ftine\Anaconda3\lib\site-packages\pandas\plotting\_core.py:2257: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   return_type=return_type, **kwds)

# %% [markdown]
# Takeaways:
# - Intersting that their are employees with high income that still leave.
# - All above fields have almost similar split for either staying or leaving.

# %%
plt.scatter(hr.MonthlyIncome, hr.Attrition, alpha=0.5)
plt.show()

# %%
sns.barplot(x="Department", y="MonthlyIncome", data=hr, hue='Attrition')

# %%
sns.barplot(x="Gender", y="MonthlyIncome", data=hr, hue='Attrition')

# %%
def age_buckets(x):
    if x <= 20: 
        return '1' 
    elif x > 20 and x <= 35: 
        return '2' 
    elif x > 35 and x <= 50: 
        return '3'  
    elif x >50: 
        return '4' 
    else: 
        return '5'
hr['AgeRange'] = hr.Age.apply(age_buckets)

sns.barplot(x="AgeRange", y="MonthlyIncome", data=hr,hue='Attrition')

# %%
ax = sns.pairplot(hr[['MonthlyIncome','Age','Attrition']], hue='Attrition')
ax.fig.set_figheight(10)
ax.fig.set_figwidth(15)

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))
#hr[hr['Attrition'] == 'Yes'].boxplot(by="Attrition",ax=ax,column=['TotalWorkingYears', 'YearsAtCompany', 'YearsSinceLastPromotion','YearsWithCurrManager'])
hr.boxplot(by="Attrition",ax=ax,column=['TotalWorkingYears', 'YearsAtCompany', 'YearsSinceLastPromotion','YearsWithCurrManager'])
plt.show()
# Out:
# C:\Users\ftine\Anaconda3\lib\site-packages\pandas\plotting\_core.py:2257: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   return_type=return_type, **kwds)

# %% [markdown]
# Takeaways:
# - Significant outliers for all fields above, but not many (in comparison) for years with current manager.
# - Again, intersting that high values of years worked (experienced employees) have left.
# - Although, insightful that low years of working and low years at company are a majority that left.
# - All above fields have almost similar split for either staying or leaving.

# %%
hr['TotalWorkingYears'][hr['Attrition']=='Yes'].value_counts(normalize=True)
# Out:
# 1.000000     0.167370
# 10.000000    0.105485
# 6.000000     0.092827
# 7.000000     0.075949
# 5.000000     0.067511
# 8.000000     0.066104
# 4.000000     0.050633
# 9.000000     0.042194
# 2.000000     0.037975
# 3.000000     0.037975
# 11.000000    0.029536
# 15.000000    0.021097
# 12.000000    0.021097
# 0.000000     0.021097
# 18.000000    0.016878
# 14.000000    0.016878
# 17.000000    0.012658
# 16.000000    0.012658
# 19.000000    0.012658
# 24.000000    0.012658
# 13.000000    0.012658
# 40.000000    0.008439
# 23.000000    0.008439
# 22.000000    0.008439
# 20.000000    0.008439
# 33.000000    0.004219
# 21.000000    0.004219
# 26.000000    0.004219
# 31.000000    0.004219
# 28.000000    0.004219
# 34.000000    0.004219
# 25.000000    0.004219
# 11.279936    0.002813
# Name: TotalWorkingYears, dtype: float64

# %%
hr['YearsAtCompany'][hr['Attrition']=='Yes'].value_counts(normalize=True)
# Out:
# 1     0.248945
# 2     0.113924
# 5     0.088608
# 3     0.084388
# 4     0.080169
# 10    0.075949
# 0     0.067511
# 7     0.046414
# 6     0.037975
# 8     0.037975
# 9     0.033755
# 13    0.008439
# 11    0.008439
# 14    0.008439
# 33    0.004219
# 15    0.004219
# 16    0.004219
# 17    0.004219
# 18    0.004219
# 19    0.004219
# 20    0.004219
# 21    0.004219
# 22    0.004219
# 23    0.004219
# 24    0.004219
# 31    0.004219
# 32    0.004219
# 40    0.004219
# Name: YearsAtCompany, dtype: float64

# %%
ax = sns.pairplot(hr[['TotalWorkingYears','YearsAtCompany','Attrition']], hue='Attrition')
ax.fig.set_figheight(10)
ax.fig.set_figwidth(15)

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5))
#hr[hr['Attrition'] == 'Yes'].boxplot(by="Attrition",ax=ax,column=['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance'])
hr.boxplot(by="Attrition",ax=ax,column=['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance'])
plt.show()
# Out:
# C:\Users\ftine\Anaconda3\lib\site-packages\pandas\plotting\_core.py:2257: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   return_type=return_type, **kwds)

# %% [markdown]
# Takeaways:
# - Environment satisfacetion is very spread our for those who have left.
# - Work life balance has almost similar split for either staying or leaving.

# %%
hr['EnvironmentSatisfaction'][hr['Attrition']=='Yes'].value_counts(normalize=True)
# Out:
# 1.000000    0.299578
# 3.000000    0.261603
# 4.000000    0.251758
# 2.000000    0.180028
# 2.723603    0.007032
# Name: EnvironmentSatisfaction, dtype: float64

# %% [markdown]
# Continue exploring with categorical variables.

# %%
sns.countplot(x='BusinessTravel',data=hr,hue='Attrition');

# %% [markdown]
# Note that employees whom do not travel a lot are less liekly to leave.

# %%
#hr.groupby('BusinessTravel')['Attrition'].value_counts(normalize=True)
hr['BusinessTravel'][hr['Attrition']=='Yes'].value_counts(normalize=True)
# Out:
# Travel_Rarely        0.658228
# Travel_Frequently    0.291139
# Non-Travel           0.050633
# Name: BusinessTravel, dtype: float64

# %%
sns.countplot(x='Department',data=hr,hue='Attrition');

# %% [markdown]
# R&D department has a the most of the employee which left the company.

# %%
#hr.groupby('Department')['Attrition'].value_counts(normalize=True)
hr['Department'][hr['Attrition']=='Yes'].value_counts(normalize=True)
# Out:
# Research & Development    0.637131
# Sales                     0.282700
# Human Resources           0.080169
# Name: Department, dtype: float64

# %%
# Check employee job satisfaction for departments.
hr.groupby(['Department','Attrition'])['JobSatisfaction'].value_counts(normalize=True)
# Out:
# Department              Attrition  JobSatisfaction
# Human Resources         No         4.000000           0.363636
#                                    1.000000           0.227273
#                                    3.000000           0.227273
#                                    2.000000           0.181818
#                         Yes        2.000000           0.263158
#                                    3.000000           0.263158
#                                    4.000000           0.263158
#                                    1.000000           0.210526
# Research & Development  No         4.000000           0.317695
#                                    3.000000           0.297942
#                                    2.000000           0.193827
#                                    1.000000           0.184362
#                                    2.728246           0.006173
#                         Yes        3.000000           0.324503
# ...

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5))
hr[hr['Department'] == 'Research & Development'].boxplot(by=["Department","Attrition"],ax=ax,column=['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance'])
#hr.boxplot(by="Department",ax=ax,column=['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance'])
plt.show()
# Out:
# C:\Users\ftine\Anaconda3\lib\site-packages\pandas\plotting\_core.py:2257: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   return_type=return_type, **kwds)

# %% [markdown]
# For R&D it seems environmwnt satisfaction is lke more imporant to stay with the firm.

# %% [markdown]
# For the remaining categorical variables lets grab some statistics.

# %%
fig, ax = plt.subplots(figsize=(20, 5))
sns.countplot(x='EducationField',data=hr,hue='Attrition');

# %%
#hr.groupby('EducationField')['Attrition'].value_counts(normalize=True)
hr['EducationField'][hr['Attrition']=='Yes'].value_counts(normalize=True)
# Out:
# Life Sciences       0.426160
# Medical             0.316456
# Marketing           0.105485
# Technical Degree    0.063291
# Human Resources     0.046414
# Other               0.042194
# Name: EducationField, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 5))
sns.countplot(x='JobRole',data=hr,hue='Attrition');

# %%
#hr.groupby('JobRole')['Attrition'].value_counts(normalize=True)
hr['JobRole'][hr['Attrition']=='Yes'].value_counts(normalize=True)
# Out:
# Sales Executive              0.232068
# Research Scientist           0.223629
# Laboratory Technician        0.177215
# Research Director            0.080169
# Healthcare Representative    0.080169
# Manufacturing Director       0.067511
# Manager                      0.059072
# Sales Representative         0.050633
# Human Resources              0.029536
# Name: JobRole, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 5))
sns.countplot(x='Attrition',data=hr,hue='Gender');

# %%
#hr.groupby('Gender')['Attrition'].value_counts(normalize=True)
hr['Gender'][hr['Attrition']=='Yes'].value_counts(normalize=True)
# Out:
# Male      0.620253
# Female    0.379747
# Name: Gender, dtype: float64

# %% [markdown]
# Now lets analyze correlation for essential fields.

# %%
# Remove non-essential fields before correlation heatmap.
hr.drop(hr[['EmployeeCount', 'Over18', 'StandardHours']], axis = 1, inplace = True)

# Build correlation heatmap.
fig = plt.figure(figsize=(20,8))
sns.heatmap(hr.corr(),annot=True)

# %%
# Encode/Convert categorical data

hr['BusinessTravel'] = hr['BusinessTravel'].map({'Travel_Frequently': 2, 'Travel_Rarely': 1, 'Non-Travel': 0})
hr['Department'] =  hr['Department'].map({'Sales': 2, 'Research & Development': 1, 'Human Resources': 0})
hr['EducationField'] = hr['EducationField'].map({'Life Sciences': 5, 'Other': 4, 'Medical': 3, 
                                             'Marketing': 2,'Technical Degree': 1,'Human Resources': 0})
hr['Gender'] = hr['Gender'].map({'Female': 1, 'Male': 0})
hr['JobRole'] = hr['JobRole'].map({'Healthcare Representative': 8, 'Research Scientist': 7, 'Sales Executive': 6, 
                                   'Human Resources': 5,'Research Director': 4,'Laboratory Technician': 3,
                                   'Manufacturing Director': 2,'Sales Representative': 1,'Manager': 0})
hr['MaritalStatus'] =  hr['MaritalStatus'].map({'Married': 2, 'Single': 1, 'Divorced': 0})
hr['Attrition'] = hr['Attrition'].map({'Yes': 1, 'No': 0})

# Check the data types
hr.dtypes
# Out:
# Age                          int64
# Attrition                    int64
# BusinessTravel               int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeID                   int64
# Gender                       int64
# JobLevel                     int64
# JobRole                      int64
# MaritalStatus                int64
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# PercentSalaryHike            int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# EnvironmentSatisfaction    float64
# JobSatisfaction            float64
# WorkLifeBalance            float64
# AgeRange                    object
# dtype: object

# %%
hr.head(5)
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0               1           2                 6          2
# 1   31          1               2           1                10          1
# 2   32          0               2           1                17          4
# 3   38          0               0           1                 2          5
# 4   32          0               1           1                10          1
#
#    EducationField  EmployeeID  Gender  JobLevel    ...     StockOptionLevel  \
# 0               5           1       1         1    ...                    0
# 1               5           2       1         1    ...                    1
# 2               4           3       0         4    ...                    3
# 3               5           4       0         3    ...                    3
# 4               3           5       0         1    ...                    2
#
# ...

# %%
# Re-reun correlation heatmap.
fig = plt.figure(figsize=(20,8))
sns.heatmap(hr.corr(),annot=True)

# %%
# Look at strong correlations and attrition
g=sns.pairplot(hr[['Age','NumCompaniesWorked','TotalWorkingYears', 'YearsAtCompany', 'YearsSinceLastPromotion','YearsWithCurrManager','Attrition']],hue='Attrition')
g.fig.set_figheight(10)
g.fig.set_figwidth(15)

# %% [markdown]
# Look at remaining fields.

# %%
sns.pairplot(hr[['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance','Attrition']],hue='Attrition')
g.fig.set_figheight(10)
g.fig.set_figwidth(15)

# %%
sns.pairplot(hr[['DistanceFromHome', 'Education','JobLevel','MonthlyIncome','Attrition']],hue='Attrition')
g.fig.set_figheight(10)
g.fig.set_figwidth(15)

# %% [markdown]
# ### Summary and next steps

# %% [markdown]
# With this level of analysis and exploring of data, there are some features that immediatley come to mind to build and fit the model. These include; job level, total working years, years at company,age, and responses from the employee satisfaction survey. Surprisingly, there were no strong correlations to attrition from the employee survey responses. Next steps, will be to run classification models and review classification metrics to return the best tuned model with a satisfactory value of predicted employees leaving the company per actual.
